# %% [markdown]
# <a href="https://colab.research.google.com/github/timothythampy/Machine-Learning/blob/master/Experiment_6/ML_Experiment_6_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler

from sklearn import linear_model
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

import warnings
warnings.filterwarnings('ignore')

np.random.seed(27)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# %matplotlib inline

plt.rcParams['figure.figsize'] = [20.0, 7.0]
plt.rcParams.update({'font.size': 22,})

sns.set_palette('viridis')
sns.set_style('white')
sns.set_context('talk', font_scale=0.8)

# %%
# !wget -O 2011gcn.csv https://raw.githubusercontent.com/pranavn91/blockchain/master/2011gcn.csv
# !wget -O tx2011partvertices_new.csv https://raw.githubusercontent.com/pranavn91/blockchain/master/tx2011partvertices_new.csv
# !wget -O tx2011partvertices.csv https://raw.githubusercontent.com/pranavn91/blockchain/master/tx2011partvertices.csv

train1 = pd.read_csv('2011gcn.csv')
train2 = pd.read_csv('tx2011partvertices_new.csv')
train3 = pd.read_csv('tx2011partvertices.csv')

print('Train 1 Shape: ', train1.shape)
print('Train 2 Shape: ', train2.shape)
print('Train 3 Shape: ', train3.shape)
# Out:
# --2020-08-30 19:14:43--  https://raw.githubusercontent.com/pranavn91/blockchain/master/2011gcn.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12563086 (12M) [text/plain]
# Saving to: ‘2011gcn.csv’
#
# 2011gcn.csv         100%[===================>]  11.98M  71.4MB/s    in 0.2s
#
# 2020-08-30 19:14:43 (71.4 MB/s) - ‘2011gcn.csv’ saved [12563086/12563086]
#
# --2020-08-30 19:14:43--  https://raw.githubusercontent.com/pranavn91/blockchain/master/tx2011partvertices_new.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12501458 (12M) [text/plain]
# Saving to: ‘tx2011partvertices_new.csv’
#
# tx2011partvertices_ 100%[===================>]  11.92M  41.0MB/s    in 0.3s
#
# 2020-08-30 19:14:44 (41.0 MB/s) - ‘tx2011partvertices_new.csv’ saved [12501458/12501458]
#
# --2020-08-30 19:14:44--  https://raw.githubusercontent.com/pranavn91/blockchain/master/tx2011partvertices.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1934257 (1.8M) [text/plain]
# Saving to: ‘tx2011partvertices.csv’
#
# tx2011partvertices. 100%[===================>]   1.84M  --.-KB/s    in 0.1s
#
# 2020-08-30 19:14:44 (14.2 MB/s) - ‘tx2011partvertices.csv’ saved [1934257/1934257]
#
# Train 1 Shape:  (96498, 17)
# Train 2 Shape:  (96498, 20)
# Train 3 Shape:  (96498, 2)

# %%
train1.rename(columns={'Unnamed: 0':'index'}, inplace=True)
train1['index'] = train1['index'] + 1
train1.head()
# Out:
#    index    0             1    2  ...   12   13            14            15
# 0      1  0.0  4.811244e+07  0.0  ...  0.0  0.0  2.670458e+07  8.313858e+07
# 1      2  0.0  3.477977e+05  0.0  ...  0.0  0.0  1.915057e+05  6.009039e+05
# 2      3  0.0  6.455196e+07  0.0  ...  0.0  0.0  3.583296e+07  1.115463e+08
# 3      4  0.0  2.009876e+08  0.0  ...  0.0  0.0  1.116514e+08  3.472892e+08
# 4      5  0.0  2.384675e+05  0.0  ...  0.0  0.0  1.315073e+05  4.120424e+05
#
# [5 rows x 17 columns]

# %%
train2.rename(columns={'Unnamed: 0':'index'}, inplace=True)
train2.head()
# Out:
#    index  txsize  txvirtualsize  ...  Total_sent  Stdev_sent  Var_sent
# 0      1    7369           7369  ...      2.1500    0.703445  0.494835
# 1      2     293            293  ...      0.0440    0.000000  0.000000
# 2      3   11139          11139  ...      1.2500    0.000000  0.000000
# 3      4     495            495  ...      0.2745    0.000000  0.000000
# 4      5     462            462  ...      0.0300    0.000000  0.000000
#
# [5 rows x 20 columns]

# %%
train3.rename(columns={'Unnamed: 0':'index'}, inplace=True)
train3.head()
# Out:
#    index         label
# 0      1  unclassified
# 1      2     donations
# 2      3  unclassified
# 3      4     donations
# 4      5     donations

# %%
train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96498 entries, 0 to 96497
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   96498 non-null  int64
#  1   0       96498 non-null  float64
#  2   1       96498 non-null  float64
#  3   2       96498 non-null  float64
#  4   3       96498 non-null  float64
#  5   4       96498 non-null  float64
#  6   5       96498 non-null  float64
#  7   6       96498 non-null  float64
#  8   7       96498 non-null  float64
#  9   8       96498 non-null  float64
#  10  9       96498 non-null  float64
#  11  10      96498 non-null  float64
#  12  11      96498 non-null  float64
#  13  12      96498 non-null  float64
#  14  13      96498 non-null  float64
#  15  14      96498 non-null  float64
#  16  15      96498 non-null  float64
# dtypes: float64(16), int64(1)
# memory usage: 12.5 MB

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96498 entries, 0 to 96497
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            96498 non-null  int64
#  1   txsize           96498 non-null  int64
#  2   txvirtualsize    96498 non-null  int64
#  3   txinputs_count   96498 non-null  int64
#  4   txoutputs_count  96498 non-null  int64
#  5   txinput_val      96498 non-null  float64
#  6   txoutput_val     96498 non-null  float64
#  7   txfee            96498 non-null  int64
#  8   Min_received     96498 non-null  float64
#  9   Max_received     96498 non-null  float64
#  10  Avg_received     96498 non-null  float64
#  11  Total_received   96498 non-null  float64
#  12  Stdev_received   96498 non-null  float64
#  13  Var_received     96498 non-null  float64
#  14  Min_sent         96498 non-null  float64
#  15  Max_sent         96498 non-null  float64
#  16  Avg_sent         96498 non-null  float64
#  17  Total_sent       96498 non-null  float64
#  18  Stdev_sent       96498 non-null  float64
#  19  Var_sent         96498 non-null  float64
# dtypes: float64(14), int64(6)
# memory usage: 14.7 MB

# %%
train3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96498 entries, 0 to 96497
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   96498 non-null  int64
#  1   label   96498 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.5+ MB

# %%
results = pd.merge(train3, train1, on='index', how='inner')

# split data into X and y
x = results.iloc[:,2:18]
Y1 = results['label']

# %%
from sklearn import preprocessing
y = pd.get_dummies(Y1)
print(x.head())
print(y.shape)
# Out:
#      0             1    2    3  ...   12   13            14            15
# 0  0.0  4.811244e+07  0.0  0.0  ...  0.0  0.0  2.670458e+07  8.313858e+07
# 1  0.0  3.477977e+05  0.0  0.0  ...  0.0  0.0  1.915057e+05  6.009039e+05
# 2  0.0  6.455196e+07  0.0  0.0  ...  0.0  0.0  3.583296e+07  1.115463e+08
# 3  0.0  2.009876e+08  0.0  0.0  ...  0.0  0.0  1.116514e+08  3.472892e+08
# 4  0.0  2.384675e+05  0.0  0.0  ...  0.0  0.0  1.315073e+05  4.120424e+05
#
# [5 rows x 16 columns]
# (96498, 6)

# %%
seed = 7
test_size = 0.4
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=seed)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size= 0.5, random_state=seed)
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (57898, 16)
# (19300, 16)
# (19300, 16)
# (57898, 6)
# (19300, 6)
# (19300, 6)

# %%
from keras import models
from keras import layers
nn = models.Sequential()


nn = models.Sequential()
nn.add(layers.Dense(512, activation = "relu", input_shape = (16,)))
nn.add(layers.Dense(128, activation = "relu"))
nn.add(layers.Dense(6, activation = "softmax"))
nn.compile(optimizer = "rmsprop", loss = 'categorical_crossentropy', 
           metrics = ['accuracy'])

nn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 512)               8704
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 75,142
# Trainable params: 75,142
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = nn.fit(x_train,y_train,epochs=100,batch_size=256,validation_data = (x_val,y_val))
# Out:
# Epoch 1/100
# 227/227 [==============================] - 1s 4ms/step - loss: 43721136.0000 - accuracy: 0.6222 - val_loss: 11417278.0000 - val_accuracy: 0.0563
# Epoch 2/100
# 227/227 [==============================] - 1s 3ms/step - loss: 22167818.0000 - accuracy: 0.6365 - val_loss: 5331467.0000 - val_accuracy: 0.8650
# Epoch 3/100
# 227/227 [==============================] - 1s 3ms/step - loss: 9212035.0000 - accuracy: 0.6198 - val_loss: 3960894.7500 - val_accuracy: 0.0699
# Epoch 4/100
# 227/227 [==============================] - 1s 3ms/step - loss: 5362290.5000 - accuracy: 0.6405 - val_loss: 3272470.0000 - val_accuracy: 0.8654
# Epoch 5/100
# 227/227 [==============================] - 1s 3ms/step - loss: 3200431.0000 - accuracy: 0.6386 - val_loss: 2014808.3750 - val_accuracy: 0.8655
# Epoch 6/100
# 227/227 [==============================] - 1s 3ms/step - loss: 1685679.7500 - accuracy: 0.6379 - val_loss: 1387672.1250 - val_accuracy: 0.0694
# Epoch 7/100
# 227/227 [==============================] - 1s 3ms/step - loss: 2003601.7500 - accuracy: 0.6528 - val_loss: 947683.2500 - val_accuracy: 0.8618
# Epoch 8/100
# 227/227 [==============================] - 1s 3ms/step - loss: 1336707.5000 - accuracy: 0.6325 - val_loss: 6086617.0000 - val_accuracy: 0.0943
# Epoch 9/100
# 227/227 [==============================] - 1s 3ms/step - loss: 908370.2500 - accuracy: 0.6187 - val_loss: 1038226.6250 - val_accuracy: 0.8645
# Epoch 10/100
# 227/227 [==============================] - 1s 3ms/step - loss: 689835.5625 - accuracy: 0.6530 - val_loss: 384730.5000 - val_accuracy: 0.8626
# Epoch 11/100
# 227/227 [==============================] - 1s 3ms/step - loss: 604355.1250 - accuracy: 0.6202 - val_loss: 1071859.3750 - val_accuracy: 0.8630
# Epoch 12/100
# 227/227 [==============================] - 1s 3ms/step - loss: 587362.2500 - accuracy: 0.6384 - val_loss: 383271.4375 - val_accuracy: 0.8651
# Epoch 13/100
# 227/227 [==============================] - 1s 3ms/step - loss: 429022.2188 - accuracy: 0.6396 - val_loss: 470057.0625 - val_accuracy: 0.8645
# Epoch 14/100
# 227/227 [==============================] - 1s 3ms/step - loss: 391486.0000 - accuracy: 0.6566 - val_loss: 265873.3750 - val_accuracy: 0.8661
# Epoch 15/100
# 227/227 [==============================] - 1s 3ms/step - loss: 229358.5469 - accuracy: 0.6436 - val_loss: 208878.0625 - val_accuracy: 0.8646
# Epoch 16/100
# 227/227 [==============================] - 1s 3ms/step - loss: 156418.0000 - accuracy: 0.6357 - val_loss: 29741.9609 - val_accuracy: 0.1110
100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6390 - accuracy: 0.8331 - val_loss: 1120.1515 - val_accuracy: 0.8347
# Epoch 74/100
# 227/227 [==============================] - 1s 3ms/step - loss: 153.9856 - accuracy: 0.8331 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 75/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6323 - accuracy: 0.8331 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 76/100
# 227/227 [==============================] - 1s 3ms/step - loss: 1869.3466 - accuracy: 0.8331 - val_loss: 0.6328 - val_accuracy: 0.8347
# Epoch 77/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6366 - accuracy: 0.8331 - val_loss: 0.6328 - val_accuracy: 0.8347
# Epoch 78/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6437 - accuracy: 0.8331 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 79/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6363 - accuracy: 0.8331 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 80/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6337 - accuracy: 0.8331 - val_loss: 0.6327 - val_accuracy: 0.8347
# Epoch 81/100
# 227/227 [==============================] - 1s 3ms/step - loss: 6416.1938 - accuracy: 0.8331 - val_loss: 0.6383 - val_accuracy: 0.8347
# Epoch 82/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6376 - accuracy: 0.8331 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 83/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6317 - accuracy: 0.8331 - val_loss: 0.6330 - val_accuracy: 0.8347
# Epoch 84/100
# 227/227 [==============================] - 1s 3ms/step - loss: 1858.5417 - accuracy: 0.8331 - val_loss: 0.6328 - val_accuracy: 0.8347
# Epoch 85/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6349 - accuracy: 0.8331 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 86/100
# 227/227 [==============================] - 1s 3ms/step - loss: 12.4084 - accuracy: 0.8330 - val_loss: 0.6330 - val_accuracy: 0.8347
# Epoch 87/100
# 227/227 [==============================] - 1s 3ms/step - loss: 5697.0342 - accuracy: 0.8294 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 88/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6430 - accuracy: 0.8330 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 89/100
# 227/227 [==============================] - 1s 3ms/step - loss: 1026.6523 - accuracy: 0.8330 - val_loss: 0.6328 - val_accuracy: 0.8347
# Epoch 90/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6325 - accuracy: 0.8331 - val_loss: 0.6555 - val_accuracy: 0.8342
# Epoch 91/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6338 - accuracy: 0.8330 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 92/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6996 - accuracy: 0.8331 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 93/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.8286 - accuracy: 0.8331 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 94/100
# 227/227 [==============================] - 1s 3ms/step - loss: 272.4099 - accuracy: 0.8298 - val_loss: 0.6330 - val_accuracy: 0.8347
# Epoch 95/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6750 - accuracy: 0.8330 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 96/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6340 - accuracy: 0.8331 - val_loss: 0.6330 - val_accuracy: 0.8347
# Epoch 97/100
# 227/227 [==============================] - 1s 3ms/step - loss: 60.6979 - accuracy: 0.8301 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 98/100
# 227/227 [==============================] - 1s 3ms/step - loss: 1.7787 - accuracy: 0.8330 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 99/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6443 - accuracy: 0.8330 - val_loss: 0.6329 - val_accuracy: 0.8347
# Epoch 100/100
# 227/227 [==============================] - 1s 3ms/step - loss: 0.6387 - accuracy: 0.8331 - val_loss: 0.6330 - val_accuracy: 0.8347

# %%
train_loss,train_accuracy = nn.evaluate(x_train,y_train)
val_loss,val_accuracy = nn.evaluate(x_val,y_val)
test_loss,test_accuracy = nn.evaluate(x_test,y_test)
print('Training Accuracy : ',train_accuracy*100,"%")
print('Val Accuracy : ',val_accuracy*100,"%")
print('Test Accuracy : ',test_accuracy*100,"%")
# Out:
# 1810/1810 [==============================] - 3s 2ms/step - loss: 0.6329 - accuracy: 0.8331
# 604/604 [==============================] - 1s 2ms/step - loss: 0.6330 - accuracy: 0.8347
# 604/604 [==============================] - 1s 2ms/step - loss: 0.6332 - accuracy: 0.8338
# Training Accuracy :  83.30512046813965 %
# Val Accuracy :  83.47150087356567 %
# Test Accuracy :  83.3834171295166 %
